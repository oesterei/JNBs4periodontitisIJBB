# %%
import os
import glob
import collections
import random

import numpy as np
from numpy import loadtxt
import pandas as pd
import scipy

import gseapy as gp #paper for GSEApy: https://academic.oup.com/bioinformatics/article/39/1/btac757/6847088
from gseapy import gseaplot

import matplotlib.pyplot as plt

# %% [markdown]
# ### Variables requiring user input - change as needed

# %%
gene_query_set_size = 500 #500 is recommended for optimal coverage without introducing statistical bias
GSEAresultsfiletitle = '\gseapy.gene_set.prerank.report.csv' #this changes if GSEApy is updated

#probe level analysis variables
zscorebool = True #set to True if you want to run z-score
Tscorebool = True #set to True if you want to run T-score
GSEAgeneIDbool = True #set to True if you want to run GSEA to identify probes of interest
genepanelbool = True #set to True if you want to define panels
moregenedatasetsbool = True #set to True if you have additional datasets for meta-analysis
randomgenemodel = True #set to True if you want ran random model for additional datasets

# %% [markdown]
# ### Functions

# %%
def data_prep(input_file_dir, output_path):
    global zscorebool, dataset_list, identification_datasets

    
    input_path_list = []    

    #get list of subdirectories - should only have "input" folder in the directory
    for path in glob.glob(f'{cwd}/*/**/', recursive=True):
        input_path_list.append(path)

    for input_path in input_path_list: #loop for more than just 1 input file (BioMOMA)
        path_split_list = input_path.split("\\")
        input_file_name = path_split_list[-2]    
        input_file_name = input_file_name[:len(input_file_name) - 5]

        #establish path variable for output directory
        all_files = []
        dataset_list = []
        samples_data_list = []

        #iterate input directory to generate a list of all files (all_files)
        for path in os.listdir(input_path):
            if os.path.isfile(os.path.join(input_path, path)): #check if current path is a file
                all_files.append(path)

        #check to see files are properly paired
        compare_dataset_IDs = []
        for file_name in all_files:
            if "samples" in file_name:
                file_name = file_name[:-11:]
                samples_data_list.append(file_name)
            elif "data" in file_name:
                file_name = file_name[:-8:]
                dataset_list.append(file_name)

        #sorting both the lists so order does not impede check
        samples_data_list.sort()
        dataset_list.sort()
        if samples_data_list != dataset_list: #using == to check if lists are equal
            print('Missing dataset or samples data file.')


        #PANEL IDENTIFICATION -------------------------------------------------------------------------------------------------
        number_ID_datasets = 0 #number of datasets that store identification data (must end up being 1 or 2)
        identification_datasets = [] #list of identification datasets


        for dataset in dataset_list:
            if dataset[-2:] == "ID": #determine if file_name is identification dataset
                if number_ID_datasets == 0:
                    probe_ID_file1 = "\\" + dataset + "data.csv" #name of first file that stores identification data
                    sample_ID_file1 = "\\" + dataset + "samples.txt" #name of file that stores sample identification data for first file
                    output_path1 = output_path + '\GSEAID' + dataset #establish path variable for identification output directory
                    output_path2 = output_path + '\GSEAID2' + dataset #establish path variable for identification output directory
                    print('The identification dataset is', dataset[:-2])
                    identification_datasets.append(dataset)
                if number_ID_datasets == 1:
                    probe_ID_file2 = "\\" + dataset + "data.csv" #name of second file, if needed, that stores identification data
                    sample_ID_file2 = "\\" + dataset + "samples.txt" #name of file that stores sample identification data for second file        
                    output_path2 = output_path + '\GSEAID' + dataset #rename path variable for identification output directory
                    print('The second identification dataset is', dataset[:-2])
                    identification_datasets.append(dataset)

                number_ID_datasets = number_ID_datasets + 1
        print()

        if zscorebool == True:
            #create output directories
            if not os.path.exists(output_gene_file_dir):
                os.mkdir(output_gene_file_dir)
            if not os.path.exists(output_path1):
                os.mkdir(output_path1)
            if not os.path.exists(output_path2):
                os.mkdir(output_path2)    

                
                
        #load first identification dataset as dataframe and format it for use    
        probe_ID_path1 = input_path + probe_ID_file1   
        raw_df1 = pd.read_csv(probe_ID_path1, low_memory = False, index_col = None, header = None, sep = ',')
        raw_df1.set_index(raw_df1.columns[0], inplace=True)

        raw_df1_sample_list = raw_df1.iloc[0].tolist()
        raw_df1.columns = raw_df1.iloc[0]
        raw_df1.drop(raw_df1.index[0], inplace = True)

        #load sample information for first identification dataset as a list and format it for use
        sample_ID_path1 = input_path + sample_ID_file1
        sample_file1 = open(sample_ID_path1, "r")
        samples1 = sample_file1.read()
        sample_list1 = samples1.split("\t")
        sample_list1[-1] = sample_list1[-1].strip()

        if len(sample_list1) == raw_df1.shape[1]:
            print('Total number of samples confirmed for the first identification dataset.')
            print()

        if number_ID_datasets == 2:
            #load second identification dataset as dataframe and format it for use
            probe_ID_path2 = input_path + probe_ID_file2
            raw_df2 = pd.read_csv(probe_ID_path2, low_memory = False, index_col = None, header = 0, sep = ',')
            raw_df2.set_index(raw_df2.columns[0], inplace=True)

            #load sample information for second identification dataset as a list and format it for use
            sample_ID_path2 = input_path + sample_ID_file2    
            sample_file2 = open(sample_ID_path2, "r")
            samples2 = sample_file2.read()
            sample_list2 = samples2.split("\t")
            sample_list2[-1] = sample_list2[-1].strip()

            if len(sample_list2) == raw_df2.shape[1]:
                print('Total number of samples confirmed for the second identification dataset.')
                print()
                
                
        #define df1 and df2
        df1 = pd.DataFrame()
        df2 = pd.DataFrame()

        #define empty variables
        control_cols1 = []
        control_cols2 = []
        experimental_cols1 = []
        experimental_cols2 = []

        num = 0 #sample counter
        if number_ID_datasets == 1:    
            #determine column index (location) of control and experimental samples for first dataset
            total_controls = []
            sample_control_list = []
            total_experimental = []
            sample_experimental_list = []

            #these variables are lists of sample indecies from df
            temp_control_cols1 = []
            temp_control_cols2 = []
            temp_experimental_cols1 = []
            temp_experimental_cols2 = []

            for i in sample_list1:
                if i == '0':
                    total_controls.append(num)
                    sample_control_list.append(raw_df1_sample_list[num])
                else:
                    total_experimental.append(num)
                    sample_experimental_list.append(raw_df1_sample_list[num])
                num = num + 1

            #assign sample identities    
            control_midpt = int(len(total_controls) / 2)
            temp_control_cols1 = total_controls[:control_midpt]
            temp_control_cols2 = total_controls[control_midpt:]

            experimental_midpt = int(len(total_experimental) / 2)
            temp_experimental_cols1 = total_experimental[:experimental_midpt]    
            temp_experimental_cols2 = total_experimental[experimental_midpt:]    

            #assign dataframes
            name_num = 0
            num = 0
            for i in temp_experimental_cols1:
                temp_col = raw_df1.iloc[:, i]       
                sample_ID = sample_experimental_list[name_num]
                df1[sample_ID] = temp_col
                experimental_cols1.append(num)
                name_num = name_num + 1
                num = num + 1

            name_num = 0
            for i in temp_control_cols1:
                temp_col = raw_df1.iloc[:, i]
                sample_ID = sample_control_list[name_num]
                df1[sample_ID] = temp_col
                control_cols1.append(num)
                name_num = name_num + 1
                num = num + 1

            name_num = len(experimental_cols1)
            num = 0
            for i in temp_experimental_cols2:
                temp_col = raw_df1.iloc[:, i]
                sample_ID = sample_experimental_list[name_num]
                df2[sample_ID] = temp_col
                experimental_cols2.append(num)
                name_num = name_num + 1
                num = num + 1

            name_num = len(control_cols1)
            for i in temp_control_cols2:
                temp_col = raw_df1.iloc[:, i]
                sample_ID = sample_control_list[name_num]
                df2[sample_ID] = temp_col
                control_cols2.append(num)
                name_num = name_num + 1
                num = num + 1

        else:    
            #assign sample identities
            for i in sample_list1:
                if i == '0':
                    control_cols1.append(num)
                else:
                    experimental_cols1.append(num)
                num = num + 1

            num = 0
            for i in sample_list2:
                if i == '0':
                    control_cols2.append(num)
                else:
                    experimental_cols2.append(num)
                num = num + 1

                #assign dataframes
                df1 = raw_df1
                df2 = raw_df2

        #check this output to ensure proper column selection
        print('Number of control samples for identification signature 1:', len(control_cols1))
        for l in control_cols1:
            print(df1.columns[l])
        print()
        print('Number of experimental samples for identification signature 1:', len(experimental_cols1))
        for l in experimental_cols1:
            print(df1.columns[l])
        print()

        print('Number of control samples for identification signature 2:', len(control_cols2))
        for l in control_cols2:
            print(df2.columns[l]) 
        print()
        print('Number of experimental samples for identification signature 2:', len(experimental_cols2))
        for l in experimental_cols2:
            print(df2.columns[l])
        print()
    return df1, df2, output_path1, output_path2, control_cols1, experimental_cols1, control_cols2, experimental_cols2

# %%
#function zscore normalizes data across all samples (columns) per gene (row) 
def zscore(df, datasetnum, loc):
    df.dropna(inplace = True)
    df.reset_index(inplace=True)
    totalrows = df[df.columns[0]].count()
    df2 = pd.DataFrame()
    tempnum = 0 #row counter variable
    
    while tempnum < totalrows:
        zscorearray = []
        temparray = df.iloc[tempnum].to_numpy()
        geneID = temparray[0]
        temparray = np.delete(temparray, 0, 0)
        temparray = temparray.astype(np.float64)

        mean = np.mean(temparray)
        std = np.std(temparray)

        for value in temparray:
            tempz = (value - mean) / std
            zscorearray = np.append(zscorearray, tempz)
        tempseries = pd.Series(zscorearray, name = geneID)
        df2 = pd.concat([df2, tempseries.to_frame().T])
        
        if tempnum % 1000 == 0:
            print('Z-scoring gene #' + str(tempnum))
        tempnum = tempnum + 1
        
    df2copy = df2
    header = list(df.head(0))
    header.pop(0)
    df2.columns = header
    filename = loc + '\Zscoredata.txt'
    df2.to_csv(filename, sep='\t', index=True)
    print('Z-score done for dataset ' + str(datasetnum))
    print()
    return df2copy

# %%
#function Tscores each gene between defined control and experimental groups
def Tscore(df, controlcols, experimentalcols, datasetnum, loc):
    dfstat = pd.DataFrame()
    dfpval = pd.DataFrame()
    tempnum = 0 #row counter variable
    
    for r in df.iterrows():
        geneID = r[0]
        row = r[1]
        controlvals = []
        experimentalvals = []
        for iter in controlcols:
            controlvals.append(row[iter])
        for iter in experimentalcols:
            experimentalvals.append(row[iter])
    
        stat, pval = scipy.stats.ttest_ind(experimentalvals, controlvals, equal_var=False)
        tempstatseries = pd.Series(stat, name = geneID)
        temppvalseries = pd.Series(pval, name = geneID)
        
        dfstat = pd.concat([dfstat, tempstatseries.to_frame().T])
        dfpval = pd.concat([dfpval, temppvalseries.to_frame().T])
        
        if tempnum % 1000 == 0:
            print('T-scoring gene #' + str(tempnum))
        tempnum = tempnum + 1
        
    dfstat.columns = ['Tscore']
    df2 = pd.concat([dfstat, dfpval], axis = 1)
    df2.columns = ['Tscore', 'pval']
    filename = loc + '\Tscoredata.txt'
    df2.to_csv(filename, sep='\t', index=True)
    dfstat = dfstat.sort_values(by=['Tscore'], ascending=False)
    print('T-score done for dataset ' + str(datasetnum))
    print()
    return dfstat

# %%
#function removes duplicate genes by finding the highest abs(Tscore) 
#function then remove genes without Tscores and adjusts centers signature
def dups(signature, datasetnum, loc):
    sigdict = {}
    num = 0

    for gene, row in signature.iterrows():
        tempTscore = signature.iloc[num]['Tscore']
        if np.isnan(tempTscore) == False:
            if gene in sigdict:   
                if abs(tempTscore) > abs(row['Tscore']):
                    sigdict.update({gene:tempTscore})
            else:
                sigdict.update({gene:row['Tscore']})
        else:
            print(gene, tempTscore)
        num = num + 1

    shortsig = pd.DataFrame(list(sigdict.items()),columns = ['Gene','Tscore']) 
    
    #center signature
    midptloc = int((len(shortsig.index)) / 2)
    midTscore = shortsig.iloc[midptloc] ['Tscore']
    newTscore = []
    
    for i, row in shortsig.iterrows():
        newval = row['Tscore'] - midTscore
        newTscore.append(float(newval))
    shortsig['Tscoreadjusted'] = newTscore
    shortsig.set_index("Gene", inplace = True)
    print('Tscores for dataset', str(datasetnum), 'were adjusted by', (-1*midTscore))
    print()
    
    filename = loc + '\signature.txt'
    shortsig.to_csv(filename, sep='\t', index=True)
    shortsig.drop('Tscore', axis=1, inplace = True)
    shortsig.rename(columns={"Tscoreadjusted": "Tscore"}, inplace=True)
    return shortsig

# %%
#function generates query sets from tails of 2 signatures established in prior functions
def query_generator(df, querysetsize, datasetnum, loc, query_num):
    global GSEAgeneIDbool, GSEApathIDbool
    
    dfquery = pd.DataFrame()
    if query_num == 1:
        dfhighest = df['Tscore'].nlargest(querysetsize)
        dflowest = df['Tscore'].nsmallest(querysetsize)
    if query_num == 2:
        dfhighest = df['NES'].nlargest(querysetsize)
        dflowest = df['NES'].nsmallest(querysetsize)

    highestlist = pd.Index.tolist(dfhighest.index)
    lowestlist = pd.Index.tolist(dflowest.index)
    
    highestlist.insert(0, ('positivetail' + str(datasetnum)))
    highestlist.insert(1, ('spacer'))
    
    lowestlist.insert(0, ('negativetail' + str(datasetnum)))
    lowestlist.insert(1, ('spacer'))
    
    highestSeries = pd.Series(highestlist)
    lowestSeries = pd.Series(lowestlist)
    dfquery = pd.concat([highestSeries, lowestSeries], axis = 1)
    dfquery = dfquery.T
    print('Query set', str(datasetnum), 'generation done!')
    print()
    return dfquery

# %%
#function performs GSEA
def prerank_GSEA(refsigdf, gene_sets, outputdir, size):
    #create GSEA results output directory
    new_output_dir = outputdir + '\GSEAresults'
    if not os.path.exists(new_output_dir):
        os.mkdir(new_output_dir)
    
    #run GSEA
    preresult = gp.prerank(rnk=refsigdf,
                     gene_sets=gene_sets,
                     min_size=15,
                     max_size=size,
                     permutation_num=1000,
                     outdir=new_output_dir,
                     seed=6,
                     verbose=False, 
                    )
    
    #print GSEA results to screen
    print(preresult.res2d.head(5))
    print()

# %% [markdown]
# ### Main program

# %%
cwd = os.getcwd() #gets current location of program file (.jpynb)

output_gene_file_dir = cwd + "\\" + "geneleveloutput" #name of directory to store output data

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Z-score code - this section of blocks determine if zscores need to be calculated and imports them if available

# %%
if zscorebool == True: #split data into 4 groups and normalize data 
    input_file_dir = cwd + "\\" + "input" #name of directory to store input data
    df1, df2, output_path1, output_path2, control_cols1, experimental_cols1, control_cols2, experimental_cols2 = data_prep(input_file_dir, output_gene_file_dir)
    
    #call function to zscore data
    normalized_df1 = zscore(df1, 1, output_path1)
    normalized_df2 = zscore(df2, 2, output_path2)
# Out:
# The identification dataset is GSE16134v1
# The second identification dataset is GSE16134v2
#
# Total number of samples confirmed for the first identification dataset.
#
# Total number of samples confirmed for the second identification dataset.
#
# Number of control samples for identification signature 1: 23
# Sample 3 from patient 4, Unaffected site
# Sample 1 from patient 5, Unaffected site
# Sample 3 from patient 3, Unaffected site
# Sample 4 from patient 2, Unaffected site
# Sample 4 from patient 1, Unaffected site
# Sample 3 from patient 8, Unaffected site
# Sample 3 from patient 9, Unaffected site
# Sample 4 from patient 10, Unaffected site
# Sample 4 from patient 12, Unaffected site
# Sample 3 from patient 13, Unaffected site
# Sample 3 from patient 113, Unaffected site
# Sample 3 from patient 108, Unaffected site
# Sample 3 from patient 102, Unaffected site
# Sample 3 from patient 107, Unaffected site
# Sample 3 from patient 106, Unaffected site
# Sample 3 from patient 92, Unaffected site
# Sample 3 from patient 93, Unaffected site
# Sample 3 from patient 98, Unaffected site
# Sample 3 from patient 95, Unaffected site
# Sample 3 from patient 94, Unaffected site
# Sample 3 from patient 91, Unaffected site
# Sample 3 from patient 86, Unaffected site
# Sample 3 from patient 87, Unaffected site
#
# Number of experimental samples for identification signature 1: 80
# Sample 1 from patient 1, Affected site
# Sample 2 from patient 1, Affected site
# Sample 1 from patient 2, Affected site
# Sample 2 from patient 2, Affected site
# Sample 1 from patient 3, Affected site
# Sample 2 from patient 3, Affected site
# Sample 1 from patient 4, Affected site
# Sample 2 from patient 4, Affected site
# Sample 2 from patient 5, Affected site
# Sample 3 from patient 5, Affected site
# Sample 1 from patient 7, Affected site
# Sample 2 from patient 7, Affected site
# Sample 3 from patient 7, Affected site
# Sample 1 from patient 8, Affected site
# Sample 2 from patient 8, Affected site
# Sample 1 from patient 9, Affected site
# Sample 2 from patient 9, Affected site
# Sample 1 from patient 10, Affected site
# Sample 2 from patient 10, Affected site
# Sample 1 from patient 11, Affected site
# Sample 2 from patient 11, Affected site
# Sample 1 from patient 12, Affected site
# Sample 2 from patient 12, Affected site
# Sample 1 from patient 13, Affected site
# Sample 2 from patient 13, Affected site
# Sample 1 from patient 14, Affected site
# Sample 2 from patient 14, Affected site
# Sample 1 from patient 15, Affected site
# Sample 2 from patient 15, Affected site
# Sample 1 from patient 16, Affected site
# Sample 2 from patient 16, Affected site
# Sample 1 from patient 17, Affected site
# Sample 2 from patient 17, Affected site
# Sample 1 from patient 18, Affected site
# Sample 2 from patient 18, Affected site
# Sample 3 from patient 18, Affected site
# Sample 2 from patient 20, Affected site
# Sample 3 from patient 20, Affected site
# Sample 1 from patient 21, Affected site
# Sample 2 from patient 21, Affected site
# Sample 1 from patient 22, Affected site
# Sample 2 from patient 22, Affected site
# Sample 1 from patient 23, Affected site
# Sample 2 from patient 23, Affected site
# Sample 1 from patient 24, Affected site
# Sample 2 from patient 24, Affected site
# Sample 1 from patient 25, Affected site
# Sample 2 from patient 25, Affected site
# Sample 1 from patient 26, Affected site
# Sample 2 from patient 26, Affected site
# Sample 1 from patient 27, Affected site
# Sample 2 from patient 27, Affected site
# Sample 2 from patient 28, Affected site
# Sample 3 from patient 28, Affected site
# Sample 1 from patient 29, Affected site
# Sample 2 from patient 29, Affected site
# Sample 1 from patient 30, Affected site
# Sample 2 from patient 30, Affected site
# Sample 1 from patient 31, Affected site
# Sample 2 from patient 31, Affected site
# Sample 1 from patient 32, Affected site
# Sample 2 from patient 32, Affected site
# Sample 1 from patient 33, Affected site
# Sample 2 from patient 33, Affected site
# Sample 1 from patient 34, Affected site
# Sample 2 from patient 34, Affected site
# Sample 1 from patient 35, Affected site
# Sample 2 from patient 35, Affected site
# Sample 1 from patient 36, Affected site
# Sample 2 from patient 36, Affected site
# Sample 1 from patient 37, Affected site
# Sample 2 from patient 37, Affected site
# Sample 1 from patient 38, Affected site
# Sample 2 from patient 38, Affected site
# Sample 1 from patient 39, Affected site
# Sample 2 from patient 39, Affected site
# Sample 1 from patient 40, Affected site
# Sample 2 from patient 40, Affected site
# Sample 1 from patient 41, Affected site
# Sample 2 from patient 41, Affected site
#
# Number of control samples for identification signature 2: 23
# Sample 3 from patient 90, Unaffected site
# Sample 3 from patient 88, Unaffected site
# Sample 3 from patient 83, Unaffected site
# Sample 3 from patient 74, Unaffected site
# Sample 3 from patient 78, Unaffected site
# Sample 3 from patient 77, Unaffected site
# Sample 3 from patient 76, Unaffected site
# Sample 3 from patient 66, Unaffected site
# Sample 3 from patient 72, Unaffected site
# Sample 3 from patient 69, Unaffected site
# Sample 3 from patient 68, Unaffected site
# Sample 4 from patient 59, Unaffected site
# Sample 4 from patient 65, Unaffected site
# Sample 3 from patient 64, Unaffected site
# Sample 3 from patient 63, Unaffected site
# Sample 3 from patient 62, Unaffected site
# Sample 4 from patient 61, Unaffected site
# Sample 3 from patient 54, Unaffected site
# Sample 3 from patient 58, Unaffected site
# Sample 4 from patient 56, Unaffected site
# Sample 3 from patient 55, Unaffected site
# Sample 4 from patient 43, Unaffected site
# Sample 3 from patient 49, Unaffected site
#
# Number of experimental samples for identification signature 2: 80
# Sample 1 from patient 42, Affected site
# Sample 2 from patient 42, Affected site
# Sample 2 from patient 43, Affected site
# Sample 1 from patient 44, Affected site
# Sample 2 from patient 44, Affected site
# Sample 1 from patient 45, Affected site
# Sample 2 from patient 45, Affected site
# Sample 1 from patient 46, Affected site
# Sample 2 from patient 46, Affected site
# Sample 1 from patient 47, Affected site
# Sample 2 from patient 47, Affected site
# Sample 1 from patient 48, Affected site
# Sample 2 from patient 48, Affected site
# Sample 1 from patient 49, Affected site
# Sample 2 from patient 49, Affected site
# Sample 1 from patient 50, Affected site
# Sample 2 from patient 50, Affected site
# Sample 1 from patient 52, Affected site
# Sample 2 from patient 52, Affected site
# Sample 2 from patient 53, Affected site
# Sample 3 from patient 53, Affected site
# Sample 1 from patient 54, Affected site
# Sample 2 from patient 54, Affected site
# Sample 1 from patient 55, Affected site
# Sample 2 from patient 55, Affected site
# Sample 1 from patient 56, Affected site
# Sample 2 from patient 56, Affected site
# Sample 1 from patient 58, Affected site
# Sample 2 from patient 58, Affected site
# Sample 1 from patient 59, Affected site
# Sample 2 from patient 59, Affected site
# Sample 1 from patient 60, Affected site
# Sample 2 from patient 60, Affected site
# Sample 1 from patient 61, Affected site
# Sample 2 from patient 61, Affected site
# Sample 1 from patient 62, Affected site
# Sample 2 from patient 62, Affected site
# Sample 1 from patient 63, Affected site
# Sample 2 from patient 63, Affected site
# Sample 1 from patient 64, Affected site
# Sample 2 from patient 64, Affected site
# Sample 1 from patient 65, Affected site
# Sample 2 from patient 65, Affected site
# Sample 1 from patient 66, Affected site
# Sample 2 from patient 66, Affected site
# Sample 1 from patient 67, Affected site
# Sample 2 from patient 67, Affected site
# Sample 1 from patient 68, Affected site
# Sample 2 from patient 68, Affected site
# Sample 1 from patient 69, Affected site
# Sample 2 from patient 69, Affected site
# Sample 1 from patient 70, Affected site
# Sample 2 from patient 70, Affected site
# Sample 1 from patient 71, Affected site
# Sample 2 from patient 71, Affected site
# Sample 1 from patient 72, Affected site
# Sample 2 from patient 72, Affected site
# Sample 1 from patient 73, Affected site
# Sample 2 from patient 73, Affected site
# Sample 1 from patient 74, Affected site
# Sample 2 from patient 74, Affected site
# Sample 1 from patient 75, Affected site
# Sample 2 from patient 75, Affected site
# Sample 1 from patient 76, Affected site
# Sample 2 from patient 76, Affected site
# Sample 1 from patient 77, Affected site
# Sample 2 from patient 77, Affected site
# Sample 1 from patient 78, Affected site
# Sample 2 from patient 78, Affected site
# Sample 1 from patient 80, Affected site
# Sample 2 from patient 80, Affected site
# Sample 1 from patient 81, Affected site
# Sample 2 from patient 81, Affected site
# Sample 1 from patient 82, Affected site
# Sample 2 from patient 82, Affected site
# Sample 1 from patient 83, Affected site
# Sample 2 from patient 83, Affected site
# Sample 1 from patient 84, Affected site
# Sample 2 from patient 84, Affected site
# Sample 1 from patient 85, Affected site
# Z-scoring gene #0
# Z-scoring gene #1000
# Z-scoring gene #2000
# Z-scoring gene #3000
# Z-scoring gene #4000
# Z-scoring gene #5000
# Z-scoring gene #6000
# Z-scoring gene #7000
# Z-scoring gene #8000
# Z-scoring gene #9000
# Z-scoring gene #10000
# Z-scoring gene #11000
# Z-scoring gene #12000
# Z-scoring gene #13000
# Z-scoring gene #14000
# Z-scoring gene #15000
# Z-scoring gene #16000
# Z-scoring gene #17000
# Z-scoring gene #18000
# Z-scoring gene #19000
# Z-scoring gene #20000
# Z-scoring gene #21000
# Z-scoring gene #22000
# Z-scoring gene #23000
# Z-scoring gene #24000
# Z-scoring gene #25000
# Z-scoring gene #26000
# Z-scoring gene #27000
# Z-scoring gene #28000
# Z-scoring gene #29000
# Z-scoring gene #30000
# Z-scoring gene #31000
# Z-scoring gene #32000
# Z-scoring gene #33000
# Z-scoring gene #34000
# Z-scoring gene #35000
# Z-scoring gene #36000
# Z-scoring gene #37000
# Z-scoring gene #38000
# Z-scoring gene #39000
# Z-scoring gene #40000
# Z-scoring gene #41000
# Z-scoring gene #42000
# Z-scoring gene #43000
# Z-scoring gene #44000
# Z-scoring gene #45000
# Z-scoring gene #46000
# Z-scoring gene #47000
# Z-scoring gene #48000
# Z-scoring gene #49000
# Z-scoring gene #50000
# Z-scoring gene #51000
# Z-scoring gene #52000
# Z-scoring gene #53000
# Z-scoring gene #54000
# Z-score done for dataset 1
#
# Z-scoring gene #0
# Z-scoring gene #1000
# Z-scoring gene #2000
# Z-scoring gene #3000
# Z-scoring gene #4000
# Z-scoring gene #5000
# Z-scoring gene #6000
# Z-scoring gene #7000
# Z-scoring gene #8000
# Z-scoring gene #9000
# Z-scoring gene #10000
# Z-scoring gene #11000
# Z-scoring gene #12000
# Z-scoring gene #13000
# Z-scoring gene #14000
# Z-scoring gene #15000
# Z-scoring gene #16000
# Z-scoring gene #17000
# Z-scoring gene #18000
# Z-scoring gene #19000
# Z-scoring gene #20000
# Z-scoring gene #21000
# Z-scoring gene #22000
# Z-scoring gene #23000
# Z-scoring gene #24000
# Z-scoring gene #25000
# Z-scoring gene #26000
# Z-scoring gene #27000
# Z-scoring gene #28000
# Z-scoring gene #29000
# Z-scoring gene #30000
# Z-scoring gene #31000
# Z-scoring gene #32000
# Z-scoring gene #33000
# Z-scoring gene #34000
# Z-scoring gene #35000
# Z-scoring gene #36000
# Z-scoring gene #37000
# Z-scoring gene #38000
# Z-scoring gene #39000
# Z-scoring gene #40000
# Z-scoring gene #41000
# Z-scoring gene #42000
# Z-scoring gene #43000
# Z-scoring gene #44000
# Z-scoring gene #45000
# Z-scoring gene #46000
# Z-scoring gene #47000
# Z-scoring gene #48000
# Z-scoring gene #49000
# Z-scoring gene #50000
# Z-scoring gene #51000
# Z-scoring gene #52000
# Z-scoring gene #53000
# Z-scoring gene #54000
# Z-score done for dataset 2

# %%
#establish a list of output folders
output_path_list = [] #list of output dictionary folders

for path in glob.glob(f'{output_gene_file_dir}/*/', recursive=True): #get list of subdirectories for \\geneleveloutput directory
    output_path_list.append(path)

# %%
if zscorebool == False:
    if Tscorebool == True: #bring in zscore files if needed for T-score function
        input_file_dir = cwd + "\\" + "input" #name of directory to store input data        
        count = 1 #local folder counter
        for i in output_path_list:
            temp_output_file_dir = i + "\\" + "Zscoredata" + str(count) + ".txt" #name of directory to store output data
            if count == 1:
                normalized_df1 = pd.read_csv(temp_output_file_dir, low_memory = False, index_col = None, header = 0, sep = '\t')
                normalized_df1.set_index(normalized_df1.columns[0], inplace=True)
                df1, df2, output_path1, output_path2, control_cols1, experimental_cols1, control_cols2, experimental_cols2 = data_prep(input_file_dir, output_file_dir)

                count = count + 1
            else:
                normalized_df2 = pd.read_csv(temp_output_file_dir, low_memory = False, index_col = None, header = 0, sep = '\t')
                normalized_df2.set_index(normalized_df2.columns[0], inplace=True)  
                df1, df2, output_path1, output_path2, control_cols1, experimental_cols1, control_cols2, experimental_cols2 = data_prep(input_file_dir, output_file_dir)
        
        print(normalized_df1)
       
    else: #Tscorebool = False
        print('This section has been skipped.')

# %% [markdown]
# #### T-score code

# %%
if Tscorebool == True: #run Tscore function from functions script
    temp_ref_sig_df1 = Tscore(normalized_df1, control_cols1, experimental_cols1, 1, output_path1)
    temp_ref_sig_df2 = Tscore(normalized_df2, control_cols2, experimental_cols2, 2, output_path2)
    
    #calls function to remove duplicates and adjust T-scored signatures
    ref_sig_df1 = dups(temp_ref_sig_df1, 1, output_path1)
    ref_sig_df2 = dups(temp_ref_sig_df2, 2, output_path2)
      
else: #Tscorebool = False
    if GSEAgeneIDbool == True: #bring in Tscore files IF NEEDED
        count = 1 #local folder counter
        for i in output_path_list:
            temp_output_file_dir = i + "\\" + "Tscoredata" + str(count) + ".txt" #name of directory to store output data
            if count == 1:
                temp_ref_sig_df1 = pd.read_csv(temp_output_file_dir, low_memory = False, index_col = None, header = 0, sep = '\t')
                temp_ref_sig_df1.set_index(temp_ref_sig_df1.columns[0], inplace=True)
                count = count + 1
            else:
                temp_ref_sig_df2 = pd.read_csv(temp_output_file_dir, low_memory = False, index_col = None, header = 0, sep = '\t')
                temp_ref_sig_df2.set_index(temp_ref_sig_df2.columns[0], inplace=True)   
        
        print(temp_ref_sig_df1)
    else:
        print('This section has been skipped.')
# Out:
# T-scoring gene #0
# T-scoring gene #1000
# T-scoring gene #2000
# T-scoring gene #3000
# T-scoring gene #4000
# T-scoring gene #5000
# T-scoring gene #6000
# T-scoring gene #7000
# T-scoring gene #8000
# T-scoring gene #9000
# T-scoring gene #10000
# T-scoring gene #11000
# T-scoring gene #12000
# T-scoring gene #13000
# T-scoring gene #14000
# T-scoring gene #15000
# T-scoring gene #16000
# T-scoring gene #17000
# T-scoring gene #18000
# T-scoring gene #19000
# T-scoring gene #20000
# T-scoring gene #21000
# T-scoring gene #22000
# T-scoring gene #23000
# T-scoring gene #24000
# T-scoring gene #25000
# T-scoring gene #26000
# T-scoring gene #27000
# T-scoring gene #28000
# T-scoring gene #29000
# T-scoring gene #30000
# T-scoring gene #31000
# T-scoring gene #32000
# T-scoring gene #33000
# T-scoring gene #34000
# T-scoring gene #35000
# T-scoring gene #36000
# T-scoring gene #37000
# T-scoring gene #38000
# T-scoring gene #39000
# T-scoring gene #40000
# T-scoring gene #41000
# T-scoring gene #42000
# T-scoring gene #43000
# T-scoring gene #44000
# T-scoring gene #45000
# T-scoring gene #46000
# T-scoring gene #47000
# T-scoring gene #48000
# T-scoring gene #49000
# T-scoring gene #50000
# T-scoring gene #51000
# T-scoring gene #52000
# T-scoring gene #53000
# T-scoring gene #54000
# T-score done for dataset 1
#
# T-scoring gene #0
# T-scoring gene #1000
# T-scoring gene #2000
# T-scoring gene #3000
# T-scoring gene #4000
# T-scoring gene #5000
# T-scoring gene #6000
# T-scoring gene #7000
# T-scoring gene #8000
# T-scoring gene #9000
# T-scoring gene #10000
# T-scoring gene #11000
# T-scoring gene #12000
# T-scoring gene #13000
# T-scoring gene #14000
# T-scoring gene #15000
# T-scoring gene #16000
# T-scoring gene #17000
# T-scoring gene #18000
# T-scoring gene #19000
# T-scoring gene #20000
# T-scoring gene #21000
# T-scoring gene #22000
# T-scoring gene #23000
# T-scoring gene #24000
# T-scoring gene #25000
# T-scoring gene #26000
# T-scoring gene #27000
# T-scoring gene #28000
# T-scoring gene #29000
# T-scoring gene #30000
# T-scoring gene #31000
# T-scoring gene #32000
# T-scoring gene #33000
# T-scoring gene #34000
# T-scoring gene #35000
# T-scoring gene #36000
# T-scoring gene #37000
# T-scoring gene #38000
# T-scoring gene #39000
# T-scoring gene #40000
# T-scoring gene #41000
# T-scoring gene #42000
# T-scoring gene #43000
# T-scoring gene #44000
# T-scoring gene #45000
# T-scoring gene #46000
# T-scoring gene #47000
# T-scoring gene #48000
# T-scoring gene #49000
# T-scoring gene #50000
# T-scoring gene #51000
# T-scoring gene #52000
# T-scoring gene #53000
# T-scoring gene #54000
# T-score done for dataset 2
#
# Tscores for dataset 1 were adjusted by 0.18901050220904078
#
# Tscores for dataset 2 were adjusted by -0.36911662183210875

# %% [markdown]
# #### GSEA

# %%
if GSEAgeneIDbool == True: #run GSEA function from functions script 
    #calls function to define query sets (4 total) from tails of the 2 signatures
    query_df1 = query_generator(ref_sig_df1, gene_query_set_size, 1, output_path1, 1) 
    query_df2 = query_generator(ref_sig_df2, gene_query_set_size, 2, output_path2, 1)
    query_df = pd.concat([query_df1, query_df2], axis = 0)
    tempinputloc = output_gene_file_dir + '\querygenesetdata.gmt'
    query_df.to_csv(tempinputloc, sep='\t', index=False, header = None)

    #calls function to perform GSEA
    inputdir = output_gene_file_dir + '\querygenesetdata.gmt'    
    
    prerank_GSEA(ref_sig_df1, inputdir, output_path1, gene_query_set_size) #need to fix to import GSEA function
    prerank_GSEA(ref_sig_df2, inputdir, output_path2, gene_query_set_size)
# Out:
# Query set 1 generation done!
#
# Query set 2 generation done!
#
#       Name           Term        ES       NES NOM p-val FDR q-val FWER p-val  \
# 0  prerank  positivetail1       1.0   5.40229       0.0       0.0        0.0
# 1  prerank  negativetail1      -1.0 -5.197684       0.0       0.0        0.0
# 2  prerank  positivetail2  0.804891  4.346815       0.0       0.0        0.0
# 3  prerank  negativetail2  -0.79198 -4.130901       0.0       0.0        0.0
#
#      Tag %  Gene %                                         Lead_genes
# 0  500/500   0.91%  211919_s_at;209201_x_at;219761_at;209499_x_at;...
# 1  500/500   0.92%  220403_s_at;227944_at;225657_at;223594_at;2360...
# 2  418/500  13.27%  219761_at;234050_at;1552542_s_at;202665_s_at;2...
# 3  387/500  13.57%  227944_at;225657_at;204141_at;236534_at;204671...
#
#       Name           Term        ES       NES NOM p-val FDR q-val FWER p-val  \
# 0  prerank  positivetail2       1.0  5.700238       0.0       0.0        0.0
# 1  prerank  negativetail2      -1.0 -4.822473       0.0       0.0        0.0
# 2  prerank  positivetail1  0.815872  4.780234       0.0       0.0        0.0
# 3  prerank  negativetail1 -0.832353  -3.99125       0.0       0.0        0.0
#
#      Tag %  Gene %                                         Lead_genes
# 0  500/500   0.91%  205303_at;1554050_at;206569_at;238759_at;20565...
# 1  500/500   0.92%  218502_s_at;220016_at;222230_s_at;211382_s_at;...
# 2  406/500  11.68%  205303_at;1554050_at;238759_at;228427_at;20604...
# 3  439/500  11.52%  220016_at;222230_s_at;211382_s_at;218898_at;21...

# %%
if genepanelbool == True: #bring in GSEA results files if needed to define gene panels
    count = 1
    for i in output_path_list:
        temp_output_file_dir = i + "\\" + 'GSEAresults' + "\\" + GSEAresultsfiletitle #name of directory to store output data
        if count == 1:
            GSEA_results1 = pd.read_csv(temp_output_file_dir, low_memory = False, index_col = "Term", header = 0, sep = ',')
            GSEA_results1.drop(['positivetail1', 'negativetail1'], inplace=True)
            count = count + 1
        else:
            GSEA_results2 = pd.read_csv(temp_output_file_dir, low_memory = False, index_col = "Term", header = 0, sep = ',')        
            GSEA_results2.drop(['positivetail2', 'negativetail2'], inplace=True)
    print('Done.')
else: #genepanelbool = False
    print('This section has been skipped.')
# Out:
# Done.

# %% [markdown]
# #### Panel definition

# %%
if genepanelbool == True:
    #check FDR for statistical significance
    FDRcol1 = GSEA_results1.iloc[:, 5]

    for i in range(len(FDRcol1)):
        if FDRcol1[i] > 0.05:
            print('FDR is too high!')
        else:
            print('FDR of', FDRcol1[i], 'is good for the first identification signature.')
    print()

    LEgenes1 = GSEA_results1.iloc[:, 8]
    
    neg_tail2 = LEgenes1.drop(['positivetail2'])
    pos_tail2 = LEgenes1.drop(['negativetail2'])

    neg_tail2 = neg_tail2.str.split(pat = ";")  
    pos_tail2 = pos_tail2.str.split(pat = ";")  
    
    #repeat for second set of GSEA results
    FDRcol2 = GSEA_results2.iloc[:, 5]

    for i in range(len(FDRcol2)):
        if FDRcol2[i] > 0.05:
            print('FDR is too high!')
        else:
            print('FDR of', FDRcol2[i], 'is good for the first identification signature.')
    print()

    LEgenes2 = GSEA_results2.iloc[:, 8]   
    
    neg_tail1 = LEgenes2.drop(['positivetail1'])
    pos_tail1 = LEgenes2.drop(['negativetail1'])

    neg_tail1 = neg_tail1.str.split(pat = ";") 
    pos_tail1 = pos_tail1.str.split(pat = ";") 
   
    temp_neg_panel = list(set(neg_tail1[0]) & set(neg_tail2[0]))
    temp_pos_panel = list(set(pos_tail1[0]) & set(pos_tail2[0]))
    
    
    ### ADD TO PANEL LIST HERE    
    pos_panel_list = []
    neg_panel_list = []
    combo_pos_panel_list = []
    combo_neg_panel_list = []    

    pos_panel_list.append(temp_pos_panel)    
    neg_panel_list.append(temp_neg_panel)  
    
    temp_neg_panel.insert(0, "negative panel")
    temp_neg_panel.insert(1, "spacer")
    temp_pos_panel.insert(0, "positive panel")
    temp_pos_panel.insert(1, "spacer")

    neg_panel = pd.Series(temp_neg_panel)
    pos_panel = pd.Series(temp_pos_panel)

    panels_file = pd.concat([pos_panel, neg_panel], axis=1)
    panels_file = panels_file.T
    
    tempinputloc = output_gene_file_dir + '\genepanels.gmt'
    panels_file.to_csv(tempinputloc, sep='\t', index=False, header = None) #name of file that stores panels in .gmt format
    
    print('Done.')
else: #genepanelbool = False
    print('This section has been skipped.')
# Out:
# FDR of 0.0 is good for the first identification signature.
# FDR of 0.0 is good for the first identification signature.
#
# FDR of 0.0 is good for the first identification signature.
# FDR of 0.0 is good for the first identification signature.
#
# Done.

# %% [markdown]
# ### Gene meta-analysis and random model

# %%
def data_prep_verify(input_path, output_path, dataset):
    global cwd, dataset_list, identification_datasets
    
    experimental_cols3 = [] #column locations of experimental sample data
    control_cols3 = [] #column locations of control sample data              
    
    #load sample identification for dataset as a list (sample_list)
    sample_compare_path = input_path + "\\" + dataset + "samples.txt"
    sample_file = open(sample_compare_path, "r")
    samples = sample_file.read()
    sample_list = samples.split("\t")
    sample_list[-1] = sample_list[-1].strip()        

    num = 0 #sample counter
    for i in sample_list:
        if i == '0':
            control_cols3.append(num)
        else:
            experimental_cols3.append(num)
        num = num + 1
        
    #load dataset as dataframe
    probe_compare_path = input_path + "\\" + dataset + "data.csv"
    df3 = pd.read_csv(probe_compare_path, low_memory = False, index_col = None, header = None, sep = ',')

    df3.set_index(df3.columns[0], inplace=True)
    df3_sample_list = df3.iloc[0].tolist()
    df3.columns = df3.iloc[0]
    df3.drop(df3.index[0], inplace = True)

    #check number of samples between two provided files
    if len(sample_list) == df3.shape[1]:
        print('Total number of samples confirmed for', dataset)
        print()

    #create output directory if one does not exist
    output_path3 = output_path + '\GSEACompare' + dataset
    if not os.path.exists(output_path3):
        os.mkdir(output_path3)

    #confirming experimental and control samples
    print('Number of control samples for', dataset, ':', len(control_cols3))
    for l in control_cols3:
        print(df3.columns[l])
    print()

    print('Number of experimental samples for', dataset, ':', len(experimental_cols3))
    for l in experimental_cols3:
        print(df3.columns[l])
    print()
        
    return df3, output_path3, control_cols3, experimental_cols3

# %%
if moregenedatasetsbool == True: #run verification functions from functions script 
    datasetnum = 3 #counte for loop for when more than 1 verification dataset
    other_datasets_output_path_list = []
        
    #remove identification dataset from dataset_list
    for dataset in identification_datasets:
        dataset_list.remove(dataset)
        
    for dataset in dataset_list: #iterate over comparison datasets
            
        df3, output_path3, control_cols3, experimental_cols3 = data_prep_verify(input_file_dir, output_gene_file_dir, dataset)   
        other_datasets_output_path_list.append(output_path3)
        
        normalized_df3 = zscore(df3, datasetnum, output_path3) #calls function to zscore data 
        temp_ref_sig_df3 = Tscore(normalized_df3, control_cols3, experimental_cols3, datasetnum, output_path3) #calls function to Tscore
        ref_sig_df3 = dups(temp_ref_sig_df3, datasetnum, output_path3) #calls function to clean Tscore signature

        inputdir = output_gene_file_dir + '\genepanels.gmt'
        prerank_GSEA(ref_sig_df3, inputdir, output_path3, gene_query_set_size) #calls function to perform GSEA
        
        datasetnum = datasetnum + 1
        
else: #moregenedatasetsbool = False
    print('This section has been skipped.')
# Out:
# Total number of samples confirmed for GSE10334all
#
# Number of control samples for GSE10334all : 64
# Gingival tissue sample 3 from patient 95, Unaffected site
# Gingival tissue sample 3 from patient 14, Unaffected site
# Gingival tissue sample 3 from patient 13, Unaffected site
# Gingival tissue sample 4 from patient 12, Unaffected site
# Gingival tissue sample 4 from patient 1, Unaffected site
# Gingival tissue sample 4 from patient 10, Unaffected site
# Gingival tissue sample 3 from patient 94, Unaffected site
# Gingival tissue sample 3 from patient 93, Unaffected site
# Gingival tissue sample 3 from patient 92, Unaffected site
# Gingival tissue sample 3 from patient 88, Unaffected site
# Gingival tissue sample 3 from patient 87, Unaffected site
# Gingival tissue sample 3 from patient 9, Unaffected site
# Gingival tissue sample 3 from patient 90, Unaffected site
# Gingival tissue sample 3 from patient 91, Unaffected site
# Gingival tissue sample 3 from patient 86, Unaffected site
# Gingival tissue sample 3 from patient 83, Unaffected site
# Gingival tissue sample 3 from patient 82, Unaffected site
# Gingival tissue sample 3 from patient 8, Unaffected site
# Gingival tissue sample 3 from patient 78, Unaffected site
# Gingival tissue sample 3 from patient 76, Unaffected site
# Gingival tissue sample 3 from patient 77, Unaffected site
# Gingival tissue sample 2 from patient 72, Unaffected site
# Gingival tissue sample 3 from patient 74, Unaffected site
# Gingival tissue sample 3 from patient 69, Unaffected site
# Gingival tissue sample 3 from patient 68, Unaffected site
# Gingival tissue sample 3 from patient 66, Unaffected site
# Gingival tissue sample 4 from patient 65, Unaffected site
# Gingival tissue sample 3 from patient 64, Unaffected site
# Gingival tissue sample 3 from patient 63, Unaffected site
# Gingival tissue sample 3 from patient 62, Unaffected site
# Gingival tissue sample 3 from patient 55, Unaffected site
# Gingival tissue sample 4 from patient 61, Unaffected site
# Gingival tissue sample 4 from patient 59, Unaffected site
# Gingival tissue sample 3 from patient 58, Unaffected site
# Gingival tissue sample 4 from patient 56, Unaffected site
# Gingival tissue sample 3 from patient 54, Unaffected site
# Gingival tissue sample 3 from patient 49, Unaffected site
# Gingival tissue sample 1 from patient 5, Unaffected site
# Gingival tissue sample 3 from patient 45, Unaffected site
# Gingival tissue sample 3 from patient 46, Unaffected site
# Gingival tissue sample 3 from patient 47, Unaffected site
# Gingival tissue sample 3 from patient 48, Unaffected site
# Gingival tissue sample 4 from patient 43, Unaffected site
# Gingival tissue sample 3 from patient 37, Unaffected site
# Gingival tissue sample 3 from patient 38, Unaffected site
# Gingival tissue sample 3 from patient 39, Unaffected site
# Gingival tissue sample 3 from patient 4, Unaffected site
# Gingival tissue sample 3 from patient 42, Unaffected site
# Gingival tissue sample 4 from patient 32, Unaffected site
# Gingival tissue sample 3 from patient 34, Unaffected site
# Gingival tissue sample 4 from patient 35, Unaffected site
# Gingival tissue sample 3 from patient 36, Unaffected site
# Gingival tissue sample 4 from patient 26, Unaffected site
# Gingival tissue sample 3 from patient 29, Unaffected site
# Gingival tissue sample 3 from patient 31, Unaffected site
# Gingival tissue sample 3 from patient 3, Unaffected site
# Gingival tissue sample 3 from patient 27, Unaffected site
# Gingival tissue sample 1 from patient 28, Unaffected site
# Gingival tissue sample 3 from patient 21, Unaffected site
# Gingival tissue sample 4 from patient 23, Unaffected site
# Gingival tissue sample 4 from patient 18, Unaffected site
# Gingival tissue sample 4 from patient 2, Unaffected site
# Gingival tissue sample 1 from patient 20, Unaffected site
# Gingival tissue sample 4 from patient 17, Unaffected site
#
# Number of experimental samples for GSE10334all : 183
# Gingival tissue sample 1 from patient 1, Affected site
# Gingival tissue sample 2 from patient 1, Affected site
# Gingival tissue sample 1 from patient 10, Affected site
# Gingival tissue sample 2 from patient 10, Affected site
# Gingival tissue sample 1 from patient 11, Affected site
# Gingival tissue sample 2 from patient 11, Affected site
# Gingival tissue sample 1 from patient 12, Affected site
# Gingival tissue sample 2 from patient 12, Affected site
# Gingival tissue sample 1 from patient 13, Affected site
# Gingival tissue sample 2 from patient 13, Affected site
# Gingival tissue sample 1 from patient 14, Affected site
# Gingival tissue sample 2 from patient 14, Affected site
# Gingival tissue sample 1 from patient 15, Affected site
# Gingival tissue sample 2 from patient 15, Affected site
# Gingival tissue sample 1 from patient 16, Affected site
# Gingival tissue sample 2 from patient 16, Affected site
# Gingival tissue sample 1 from patient 17, Affected site
# Gingival tissue sample 2 from patient 17, Affected site
# Gingival tissue sample 1 from patient 18, Affected site
# Gingival tissue sample 2 from patient 18, Affected site
# Gingival tissue sample 3 from patient 18, Affected site
# Gingival tissue sample 1 from patient 2, Affected site
# Gingival tissue sample 2 from patient 2, Affected site
# Gingival tissue sample 2 from patient 20, Affected site
# Gingival tissue sample 3 from patient 20, Affected site
# Gingival tissue sample 1 from patient 21, Affected site
# Gingival tissue sample 2 from patient 21, Affected site
# Gingival tissue sample 1 from patient 22, Affected site
# Gingival tissue sample 2 from patient 22, Affected site
# Gingival tissue sample 1 from patient 23, Affected site
# Gingival tissue sample 2 from patient 23, Affected site
# Gingival tissue sample 1 from patient 24, Affected site
# Gingival tissue sample 2 from patient 24, Affected site
# Gingival tissue sample 1 from patient 25, Affected site
# Gingival tissue sample 2 from patient 25, Affected site
# Gingival tissue sample 1 from patient 26, Affected site
# Gingival tissue sample 2 from patient 26, Affected site
# Gingival tissue sample 1 from patient 27, Affected site
# Gingival tissue sample 2 from patient 27, Affected site
# Gingival tissue sample 2 from patient 28, Affected site
# Gingival tissue sample 3 from patient 28, Affected site
# Gingival tissue sample 1 from patient 29, Affected site
# Gingival tissue sample 2 from patient 29, Affected site
# Gingival tissue sample 1 from patient 3, Affected site
# Gingival tissue sample 2 from patient 3, Affected site
# Gingival tissue sample 1 from patient 30, Affected site
# Gingival tissue sample 2 from patient 30, Affected site
# Gingival tissue sample 1 from patient 31, Affected site
# Gingival tissue sample 2 from patient 31, Affected site
# Gingival tissue sample 1 from patient 32, Affected site
# Gingival tissue sample 2 from patient 32, Affected site
# Gingival tissue sample 1 from patient 33, Affected site
# Gingival tissue sample 2 from patient 33, Affected site
# Gingival tissue sample 1 from patient 34, Affected site
# Gingival tissue sample 2 from patient 34, Affected site
# Gingival tissue sample 1 from patient 35, Affected site
# Gingival tissue sample 2 from patient 35, Affected site
# Gingival tissue sample 1 from patient 36, Affected site
# Gingival tissue sample 2 from patient 36, Affected site
# Gingival tissue sample 1 from patient 37, Affected site
# Gingival tissue sample 2 from patient 37, Affected site
# Gingival tissue sample 1 from patient 38, Affected site
# Gingival tissue sample 2 from patient 38, Affected site
# Gingival tissue sample 1 from patient 39, Affected site
# Gingival tissue sample 2 from patient 39, Affected site
# Gingival tissue sample 1 from patient 4, Affected site
# Gingival tissue sample 2 from patient 4, Affected site
# Gingival tissue sample 1 from patient 40, Affected site
# Gingival tissue sample 2 from patient 40, Affected site
# Gingival tissue sample 1 from patient 41, Affected site
# Gingival tissue sample 2 from patient 41, Affected site
# Gingival tissue sample 1 from patient 42, Affected site
# Gingival tissue sample 2 from patient 42, Affected site
# Gingival tissue sample 4 from patient 42, Affected site
# Gingival tissue sample 1 from patient 43, Affected site
# Gingival tissue sample 2 from patient 43, Affected site
# Gingival tissue sample 1 from patient 44, Affected site
# Gingival tissue sample 2 from patient 44, Affected site
# Gingival tissue sample 1 from patient 45, Affected site
# Gingival tissue sample 2 from patient 45, Affected site
# Gingival tissue sample 1 from patient 46, Affected site
# Gingival tissue sample 2 from patient 46, Affected site
# Gingival tissue sample 1 from patient 47, Affected site
# Gingival tissue sample 2 from patient 47, Affected site
# Gingival tissue sample 1 from patient 48, Affected site
# Gingival tissue sample 2 from patient 48, Affected site
# Gingival tissue sample 1 from patient 49, Affected site
# Gingival tissue sample 2 from patient 49, Affected site
# Gingival tissue sample 2 from patient 5, Affected site
# Gingival tissue sample 3 from patient 5, Affected site
# Gingival tissue sample 1 from patient 50, Affected site
# Gingival tissue sample 2 from patient 50, Affected site
# Gingival tissue sample 1 from patient 52, Affected site
# Gingival tissue sample 2 from patient 52, Affected site
# Gingival tissue sample 2 from patient 53, Affected site
# Gingival tissue sample 3 from patient 53, Affected site
# Gingival tissue sample 1 from patient 54, Affected site
# Gingival tissue sample 2 from patient 54, Affected site
# Gingival tissue sample 1 from patient 55, Affected site
# Gingival tissue sample 2 from patient 55, Affected site
# Gingival tissue sample 1 from patient 56, Affected site
# Gingival tissue sample 2 from patient 56, Affected site
# Gingival tissue sample 1 from patient 58, Affected site
# Gingival tissue sample 2 from patient 58, Affected site
# Gingival tissue sample 1 from patient 59, Affected site
# Gingival tissue sample 2 from patient 59, Affected site
# Gingival tissue sample 1 from patient 60, Affected site
# Gingival tissue sample 2 from patient 60, Affected site
# Gingival tissue sample 1 from patient 61, Affected site
# Gingival tissue sample 2 from patient 61, Affected site
# Gingival tissue sample 1 from patient 62, Affected site
# Gingival tissue sample 2 from patient 62, Affected site
# Gingival tissue sample 1 from patient 63, Affected site
# Gingival tissue sample 2 from patient 63, Affected site
# Gingival tissue sample 1 from patient 64, Affected site
# Gingival tissue sample 2 from patient 64, Affected site
# Gingival tissue sample 1 from patient 65, Affected site
# Gingival tissue sample 2 from patient 65, Affected site
# Gingival tissue sample 1 from patient 66, Affected site
# Gingival tissue sample 2 from patient 66, Affected site
# Gingival tissue sample 1 from patient 67, Affected site
# Gingival tissue sample 2 from patient 67, Affected site
# Gingival tissue sample 1 from patient 68, Affected site
# Gingival tissue sample 2 from patient 68, Affected site
# Gingival tissue sample 1 from patient 69, Affected site
# Gingival tissue sample 2 from patient 69, Affected site
# Gingival tissue sample 1 from patient 7, Affected site
# Gingival tissue sample 2 from patient 7, Affected site
# Gingival tissue sample 3 from patient 7, Affected site
# Gingival tissue sample 1 from patient 70, Affected site
# Gingival tissue sample 2 from patient 70, Affected site
# Gingival tissue sample 1 from patient 71, Affected site
# Gingival tissue sample 2 from patient 71, Affected site
# Gingival tissue sample 1 from patient 72, Affected site
# Gingival tissue sample 3 from patient 72, Affected site
# Gingival tissue sample 1 from patient 73, Affected site
# Gingival tissue sample 2 from patient 73, Affected site
# Gingival tissue sample 1 from patient 74, Affected site
# Gingival tissue sample 2 from patient 74, Affected site
# Gingival tissue sample 1 from patient 75, Affected site
# Gingival tissue sample 2 from patient 75, Affected site
# Gingival tissue sample 1 from patient 76, Affected site
# Gingival tissue sample 2 from patient 76, Affected site
# Gingival tissue sample 1 from patient 77, Affected site
# Gingival tissue sample 2 from patient 77, Affected site
# Gingival tissue sample 1 from patient 78, Affected site
# Gingival tissue sample 2 from patient 78, Affected site
# Gingival tissue sample 1 from patient 8, Affected site
# Gingival tissue sample 2 from patient 8, Affected site
# Gingival tissue sample 1 from patient 80, Affected site
# Gingival tissue sample 2 from patient 80, Affected site
# Gingival tissue sample 1 from patient 81, Affected site
# Gingival tissue sample 2 from patient 81, Affected site
# Gingival tissue sample 1 from patient 82, Affected site
# Gingival tissue sample 2 from patient 82, Affected site
# Gingival tissue sample 1 from patient 83, Affected site
# Gingival tissue sample 2 from patient 83, Affected site
# Gingival tissue sample 1 from patient 84, Affected site
# Gingival tissue sample 2 from patient 84, Affected site
# Gingival tissue sample 1 from patient 85, Affected site
# Gingival tissue sample 2 from patient 85, Affected site
# Gingival tissue sample 1 from patient 86, Affected site
# Gingival tissue sample 2 from patient 86, Affected site
# Gingival tissue sample 1 from patient 87, Affected site
# Gingival tissue sample 2 from patient 87, Affected site
# Gingival tissue sample 1 from patient 88, Affected site
# Gingival tissue sample 2 from patient 88, Affected site
# Gingival tissue sample 1 from patient 89, Affected site
# Gingival tissue sample 2 from patient 89, Affected site
# Gingival tissue sample 1 from patient 9, Affected site
# Gingival tissue sample 2 from patient 9, Affected site
# Gingival tissue sample 1 from patient 90, Affected site
# Gingival tissue sample 2 from patient 90, Affected site
# Gingival tissue sample 1 from patient 91, Affected site
# Gingival tissue sample 2 from patient 91, Affected site
# Gingival tissue sample 1 from patient 92, Affected site
# Gingival tissue sample 2 from patient 92, Affected site
# Gingival tissue sample 1 from patient 93, Affected site
# Gingival tissue sample 2 from patient 93, Affected site
# Gingival tissue sample 1 from patient 94, Affected site
# Gingival tissue sample 2 from patient 94, Affected site
# Gingival tissue sample 1 from patient 95, Affected site
# Gingival tissue sample 2 from patient 95, Affected site
# Z-scoring gene #0
# Z-scoring gene #1000
# Z-scoring gene #2000
# Z-scoring gene #3000
# Z-scoring gene #4000
# Z-scoring gene #5000
# Z-scoring gene #6000
# Z-scoring gene #7000
# Z-scoring gene #8000
# Z-scoring gene #9000
# Z-scoring gene #10000
# Z-scoring gene #11000
# Z-scoring gene #12000
# Z-scoring gene #13000
# Z-scoring gene #14000
# Z-scoring gene #15000
# Z-scoring gene #16000
# Z-scoring gene #17000
# Z-scoring gene #18000
# Z-scoring gene #19000
# Z-scoring gene #20000
# Z-scoring gene #21000
# Z-scoring gene #22000
# Z-scoring gene #23000
# Z-scoring gene #24000
# Z-scoring gene #25000
# Z-scoring gene #26000
# Z-scoring gene #27000
# Z-scoring gene #28000
# Z-scoring gene #29000
# Z-scoring gene #30000
# Z-scoring gene #31000
# Z-scoring gene #32000
# Z-scoring gene #33000
# Z-scoring gene #34000
# Z-scoring gene #35000
# Z-scoring gene #36000
# Z-scoring gene #37000
# Z-scoring gene #38000
# Z-scoring gene #39000
# Z-scoring gene #40000
# Z-scoring gene #41000
# Z-scoring gene #42000
# Z-scoring gene #43000
# Z-scoring gene #44000
# Z-scoring gene #45000
# Z-scoring gene #46000
# Z-scoring gene #47000
# Z-scoring gene #48000
# Z-scoring gene #49000
# Z-scoring gene #50000
# Z-scoring gene #51000
# Z-scoring gene #52000
# Z-scoring gene #53000
# Z-scoring gene #54000
# Z-score done for dataset 3
#
# T-scoring gene #0
# T-scoring gene #1000
# T-scoring gene #2000
# T-scoring gene #3000
# T-scoring gene #4000
# T-scoring gene #5000
# T-scoring gene #6000
# T-scoring gene #7000
# T-scoring gene #8000
# T-scoring gene #9000
# T-scoring gene #10000
# T-scoring gene #11000
# T-scoring gene #12000
# T-scoring gene #13000
# T-scoring gene #14000
# T-scoring gene #15000
# T-scoring gene #16000
# T-scoring gene #17000
# T-scoring gene #18000
# T-scoring gene #19000
# T-scoring gene #20000
# T-scoring gene #21000
# T-scoring gene #22000
# T-scoring gene #23000
# T-scoring gene #24000
# T-scoring gene #25000
# T-scoring gene #26000
# T-scoring gene #27000
# T-scoring gene #28000
# T-scoring gene #29000
# T-scoring gene #30000
# T-scoring gene #31000
# T-scoring gene #32000
# T-scoring gene #33000
# T-scoring gene #34000
# T-scoring gene #35000
# T-scoring gene #36000
# T-scoring gene #37000
# T-scoring gene #38000
# T-scoring gene #39000
# T-scoring gene #40000
# T-scoring gene #41000
# T-scoring gene #42000
# T-scoring gene #43000
# T-scoring gene #44000
# T-scoring gene #45000
# T-scoring gene #46000
# T-scoring gene #47000
# T-scoring gene #48000
# T-scoring gene #49000
# T-scoring gene #50000
# T-scoring gene #51000
# T-scoring gene #52000
# T-scoring gene #53000
# T-scoring gene #54000
# T-score done for dataset 3
#
# Tscores for dataset 3 were adjusted by -0.24182741291372065
#
#       Name            Term        ES       NES NOM p-val FDR q-val FWER p-val  \
# 0  prerank  positive panel  0.955429  4.423605       0.0       0.0        0.0
# 1  prerank  negative panel -0.969668 -3.866868       0.0       0.0        0.0
#
#      Tag % Gene %                                         Lead_genes
# 0  110/110  4.65%  204683_at;228427_at;228003_at;203921_at;236191...
# 1  113/113  3.24%  218898_at;226188_at;204141_at;202428_x_at;2383...
#
# Total number of samples confirmed for GSE16134verify
#
# Number of control samples for GSE16134verify : 23
# Sample 3 from patient 48, Unaffected site
# Sample 3 from patient 47, Unaffected site
# Sample 3 from patient 46, Unaffected site
# Sample 3 from patient 45, Unaffected site
# Sample 3 from patient 42, Unaffected site
# Sample 3 from patient 39, Unaffected site
# Sample 3 from patient 38, Unaffected site
# Sample 3 from patient 37, Unaffected site
# Sample 3 from patient 36, Unaffected site
# Sample 3 from patient 29, Unaffected site
# Sample 4 from patient 35, Unaffected site
# Sample 3 from patient 34, Unaffected site
# Sample 4 from patient 32, Unaffected site
# Sample 3 from patient 31, Unaffected site
# Sample 3 from patient 27, Unaffected site
# Sample 1 from patient 28, Unaffected site
# Sample 4 from patient 26, Unaffected site
# Sample 4 from patient 23, Unaffected site
# Sample 3 from patient 21, Unaffected site
# Sample 1 from patient 20, Unaffected site
# Sample 3 from patient 14, Unaffected site
# Sample 4 from patient 18, Unaffected site
# Sample 4 from patient 17, Unaffected site
#
# Number of experimental samples for GSE16134verify : 81
# Sample 2 from patient 85, Affected site
# Sample 1 from patient 86, Affected site
# Sample 2 from patient 86, Affected site
# Sample 1 from patient 87, Affected site
# Sample 2 from patient 87, Affected site
# Sample 1 from patient 88, Affected site
# Sample 2 from patient 88, Affected site
# Sample 1 from patient 89, Affected site
# Sample 2 from patient 89, Affected site
# Sample 1 from patient 90, Affected site
# Sample 2 from patient 90, Affected site
# Sample 1 from patient 91, Affected site
# Sample 2 from patient 91, Affected site
# Sample 1 from patient 92, Affected site
# Sample 2 from patient 92, Affected site
# Sample 1 from patient 93, Affected site
# Sample 2 from patient 93, Affected site
# Sample 1 from patient 94, Affected site
# Sample 2 from patient 94, Affected site
# Sample 1 from patient 95, Affected site
# Sample 2 from patient 95, Affected site
# Sample 1 from patient 98, Affected site
# Sample 2 from patient 98, Affected site
# Sample 1 from patient 99, Affected site
# Sample 2 from patient 99, Affected site
# Sample 1 from patient 100, Affected site
# Sample 2 from patient 100, Affected site
# Sample 2 from patient 101, Affected site
# Sample 3 from patient 101, Affected site
# Sample 1 from patient 102, Affected site
# Sample 2 from patient 102, Affected site
# Sample 1 from patient 104, Affected site
# Sample 2 from patient 104, Affected site
# Sample 1 from patient 105, Affected site
# Sample 2 from patient 105, Affected site
# Sample 1 from patient 106, Affected site
# Sample 2 from patient 106, Affected site
# Sample 1 from patient 107, Affected site
# Sample 2 from patient 107, Affected site
# Sample 1 from patient 108, Affected site
# Sample 2 from patient 108, Affected site
# Sample 1 from patient 109, Affected site
# Sample 2 from patient 109, Affected site
# Sample 1 from patient 110, Affected site
# Sample 2 from patient 110, Affected site
# Sample 1 from patient 111, Affected site
# Sample 2 from patient 111, Affected site
# Sample 1 from patient 112, Affected site
# Sample 2 from patient 112, Affected site
# Sample 1 from patient 113, Affected site
# Sample 2 from patient 113, Affected site
# Sample 1 from patient 115, Affected site
# Sample 2 from patient 115, Affected site
# Sample 1 from patient 116, Affected site
# Sample 2 from patient 116, Affected site
# Sample 1 from patient 117, Affected site
# Sample 2 from patient 117, Affected site
# Sample 1 from patient 118, Affected site
# Sample 2 from patient 118, Affected site
# Sample 1 from patient 119, Affected site
# Sample 2 from patient 119, Affected site
# Sample 1 from patient 120, Affected site
# Sample 2 from patient 120, Affected site
# Sample 1 from patient 121, Affected site
# Sample 2 from patient 121, Affected site
# Sample 1 from patient 123, Affected site
# Sample 2 from patient 123, Affected site
# Sample 1 from patient 124, Affected site
# Sample 2 from patient 124, Affected site
# Sample 1 from patient 125, Affected site
# Sample 2 from patient 125, Affected site
# Sample 1 from patient 126, Affected site
# Sample 2 from patient 126, Affected site
# Sample 1 from patient 127, Affected site
# Sample 2 from patient 127, Affected site
# Sample 1 from patient 129, Affected site
# Sample 2 from patient 129, Affected site
# Sample 1 from patient 130, Affected site
# Sample 2 from patient 130, Affected site
# Sample 1 from patient 131, Affected site
# Sample 2 from patient 131, Affected site
#
# Z-scoring gene #0
# Z-scoring gene #1000
# Z-scoring gene #2000
# Z-scoring gene #3000
# Z-scoring gene #4000
# Z-scoring gene #5000
# Z-scoring gene #6000
# Z-scoring gene #7000
# Z-scoring gene #8000
# Z-scoring gene #9000
# Z-scoring gene #10000
# Z-scoring gene #11000
# Z-scoring gene #12000
# Z-scoring gene #13000
# Z-scoring gene #14000
# Z-scoring gene #15000
# Z-scoring gene #16000
# Z-scoring gene #17000
# Z-scoring gene #18000
# Z-scoring gene #19000
# Z-scoring gene #20000
# Z-scoring gene #21000
# Z-scoring gene #22000
# Z-scoring gene #23000
# Z-scoring gene #24000
# Z-scoring gene #25000
# Z-scoring gene #26000
# Z-scoring gene #27000
# Z-scoring gene #28000
# Z-scoring gene #29000
# Z-scoring gene #30000
# Z-scoring gene #31000
# Z-scoring gene #32000
# Z-scoring gene #33000
# Z-scoring gene #34000
# Z-scoring gene #35000
# Z-scoring gene #36000
# Z-scoring gene #37000
# Z-scoring gene #38000
# Z-scoring gene #39000
# Z-scoring gene #40000
# Z-scoring gene #41000
# Z-scoring gene #42000
# Z-scoring gene #43000
# Z-scoring gene #44000
# Z-scoring gene #45000
# Z-scoring gene #46000
# Z-scoring gene #47000
# Z-scoring gene #48000
# Z-scoring gene #49000
# Z-scoring gene #50000
# Z-scoring gene #51000
# Z-scoring gene #52000
# Z-scoring gene #53000
# Z-scoring gene #54000
# Z-score done for dataset 4
#
# T-scoring gene #0
# T-scoring gene #1000
# T-scoring gene #2000
# T-scoring gene #3000
# T-scoring gene #4000
# T-scoring gene #5000
# T-scoring gene #6000
# T-scoring gene #7000
# T-scoring gene #8000
# T-scoring gene #9000
# T-scoring gene #10000
# T-scoring gene #11000
# T-scoring gene #12000
# T-scoring gene #13000
# T-scoring gene #14000
# T-scoring gene #15000
# T-scoring gene #16000
# T-scoring gene #17000
# T-scoring gene #18000
# T-scoring gene #19000
# T-scoring gene #20000
# T-scoring gene #21000
# T-scoring gene #22000
# T-scoring gene #23000
# T-scoring gene #24000
# T-scoring gene #25000
# T-scoring gene #26000
# T-scoring gene #27000
# T-scoring gene #28000
# T-scoring gene #29000
# T-scoring gene #30000
# T-scoring gene #31000
# T-scoring gene #32000
# T-scoring gene #33000
# T-scoring gene #34000
# T-scoring gene #35000
# T-scoring gene #36000
# T-scoring gene #37000
# T-scoring gene #38000
# T-scoring gene #39000
# T-scoring gene #40000
# T-scoring gene #41000
# T-scoring gene #42000
# T-scoring gene #43000
# T-scoring gene #44000
# T-scoring gene #45000
# T-scoring gene #46000
# T-scoring gene #47000
# T-scoring gene #48000
# T-scoring gene #49000
# T-scoring gene #50000
# T-scoring gene #51000
# T-scoring gene #52000
# T-scoring gene #53000
# T-scoring gene #54000
# T-score done for dataset 4
#
# Tscores for dataset 4 were adjusted by 0.46284814782826267
#
#       Name            Term        ES       NES NOM p-val FDR q-val FWER p-val  \
# 0  prerank  positive panel   0.83261   3.66644       0.0       0.0        0.0
# 1  prerank  negative panel -0.683731 -3.354245       0.0       0.0        0.0
#
#     Tag %  Gene %                                         Lead_genes
# 0  88/110  10.86%  228003_at;204683_at;208451_s_at;212311_at;2060...
# 1  71/113  14.56%  236616_at;229062_at;226188_at;218898_at;203303...

# %% [markdown]
# #### Random modelling

# %%
def shuffle(verifysigdf):
    
    #determine average size of defined panels
    inputdir = output_gene_file_dir + '\genepanels.gmt'        
    dfpanel = pd.read_csv(inputdir, low_memory=False, delimiter = "\t", header=None)

    tempsum = 0
    for row in dfpanel.iterrows():
        listrow = list(row[1])
        newlist = [x for x in listrow if pd.isnull(x) == False and x != 'nan']   
        panellen = (len(newlist))-2
        tempsum = tempsum + panellen
    averagesize = tempsum/2
    
    #generate random gene sets of the same size as the average size of defined panels
    df3 = pd.DataFrame()
    
    verifysigdf = verifysigdf.set_index('Gene')
    listofgenes = verifysigdf.index
    listofgenes = list(verifysigdf.index)
    querysize = int(averagesize)
    for i in range(1000):
        random.shuffle(listofgenes)
        temprandomlist = listofgenes[0:querysize]
        temprandomlist.insert(0, ('random' + str(i)))
        temprandomlist.insert(1, 'spacer')
        a_series = pd.Series(temprandomlist)
        df3 = pd.concat([df3, a_series], axis=1)
        if i % 100 == 0:
            print('Random list #' + str(i))
    df3 = df3.T
    return df3

# %%
if randomgenemodel == True:
    for output_path in other_datasets_output_path_list: #iterate over comparison datasets
        #bring in other dataset signature
        verify_sig_file = output_path + '\signature.txt'
        verify_sig_df = pd.read_csv(verify_sig_file, low_memory = False, index_col = None, header = 0, sep = '\t')
        verify_sig_df.drop(['Tscore'], axis = 1, inplace = True)
        
        #generate random panels
        randompanel = shuffle(verify_sig_df)
        randompanel.to_csv((output_gene_file_dir + '\\' + 'randompaneldata.gmt'), sep='\t', index=False, header=False)

        #create output directory if one does not exist
        random_output_path = output_path + "\\" + 'random'
        if not os.path.exists(random_output_path):
            os.mkdir(random_output_path)

        #run GSEA to generate null distibution of NES
        dfrandomNES = prerank_GSEA(verify_sig_df, (output_gene_file_dir + '\\' + 'randompaneldata.gmt'), random_output_path, gene_query_set_size) 
                
        #visualize the results
        #first get random model NES
        dfrandomNES = pd.read_csv((random_output_path + "\\" + 'GSEAresults' + "\\" + GSEAresultsfiletitle), low_memory=False)
        dfrandomNEScol = dfrandomNES["NES"]
        
        #next get panel achieved NES
        dfNES = pd.read_csv((output_path + "\\" + 'GSEAresults' + "\\" + GSEAresultsfiletitle), low_memory=False)
        dfNEScol = dfNES["NES"]
        
        pospanel = dfNEScol[1]
        if pospanel < 0:
            negpanel = pospanel
            pospanel = dfNEScol[0]

        else:
            negpanel = dfNEScol[0]

        #box and whiskars the results
        fig, ax = plt.subplots()
        line1 = ax.boxplot(dfrandomNEScol, vert=0, patch_artist=True, meanline=True, showmeans=True)
        line2 = ax.scatter(pospanel, 1, marker="D", color = "red", label = "positive panel")
        line3 = ax.scatter(negpanel, 1, marker="D", color = "blue", label = "negative panel")
        plt.yticks([1], [''])
        plt.xlabel('Randomly Generated Normalized Enrichment Scores')
        ax.legend(handles=[line2, line3])
        saveloc = output_path + '\\randomNESboxwhisplot.png'
        plt.savefig(saveloc, dpi=100)
        plt.show()

else: #randommodel = False
    print('This section has been skipped.')
# Out:
# Random list #0
# Random list #100
# Random list #200
# Random list #300
# Random list #400
# Random list #500
# Random list #600
# Random list #700
# Random list #800
# Random list #900
#       Name       Term        ES       NES NOM p-val FDR q-val FWER p-val  \
# 0  prerank  random325 -0.436292 -1.745381       0.0  0.143876      0.138
# 1  prerank  random245 -0.397068 -1.590226  0.001279  0.902895      0.855
# 2  prerank   random79 -0.384896 -1.550918  0.002541       1.0      0.964
# 3  prerank  random238 -0.388009 -1.546384  0.005249  0.843436      0.967
# 4  prerank  random680 -0.378966 -1.525611  0.006378  0.877154       0.99
#
#     Tag %  Gene %                                         Lead_genes
# 0  49/111  26.78%  228587_at;226908_at;212711_at;237038_at;242289...
# 1  34/111  20.95%  201472_at;225188_at;225162_at;218428_s_at;2171...
# 2  29/111  14.77%  227944_at;201131_s_at;33323_r_at;227698_s_at;2...
# 3  33/111  20.46%  232116_at;1556793_a_at;225538_at;226382_at;205...
# 4  34/111  18.89%  224345_x_at;218111_s_at;209028_s_at;213927_at;...
# Random list #0
# Random list #100
# Random list #200
# Random list #300
# Random list #400
# Random list #500
# Random list #600
# Random list #700
# Random list #800
# Random list #900
#       Name       Term        ES       NES NOM p-val FDR q-val FWER p-val  \
# 0  prerank  random575  0.380196  1.665464       0.0  0.877586      0.575
# 1  prerank  random871   0.37599  1.652162  0.004115  0.537204      0.647
# 2  prerank  random704 -0.319464  -1.65168       0.0  0.203255       0.19
# 3  prerank  random742  0.366162  1.613144  0.003901  0.625977      0.846
# 4  prerank  random401  0.360204  1.581707  0.005319  0.703844      0.946
#
#     Tag %  Gene %                                         Lead_genes
# 0  41/111  22.08%  205671_s_at;203188_at;217198_x_at;204785_x_at;...
# 1  30/111  14.67%  228390_at;204361_s_at;204158_s_at;227289_at;20...
# 2  30/111  12.59%  207953_at;221171_at;1556255_a_at;1558723_at;58...
# 3  38/111  22.57%  221449_s_at;212345_s_at;215118_s_at;208018_s_a...
# 4  43/111  24.73%  221551_x_at;239118_at;205267_at;217145_at;2334...
